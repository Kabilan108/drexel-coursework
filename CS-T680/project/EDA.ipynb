# %% [markdown]
# # Exploratory Data Analysis
#
# **Abbreviations:**
# - *ASD* - Autism Spectrum Disorder
# - *TDC* - Typically-Developing Control
# - *ADOS_CSS* - Autism Diagnostic Observation Schedule Calibrated Severity Scores
# - *SCQ* - Social-Communication Questionnare

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.display import display
import ipywidgets as widgets

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import glob
import os

# %%
# Paths & settings
class PATH:
    data = '../data/CHARM'  # Path to data directory
    desikan_atlas = f"{data}/Desikan_sift2"  # atlas path
    schaefer_atlas = f"{data}/Schaefer200_sift2"  # atlas path

# Working directory
os.chdir("/home/kabil/tko35/CS-T680/project")

# %% [markdown]
# ## DI Check

# %%
# Load demographics information
demographics = pd.read_csv(data_path + '/tobacco_demographics.csv')
demographics.info()

# 335 patients
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Subject    335 non-null    object
#  1   Sex        335 non-null    object
#  2   Age        335 non-null    float64
#  3   DX         335 non-null    object
#  4   ados_css   190 non-null    float64
#  5   scq_total  325 non-null    float64
#  6   iq         331 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 18.4+ KB

# %%
# Check data files
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 335 entries, 0 to 334
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Subject    335 non-null    object
#  1   Sex        335 non-null    object
#  2   Age        335 non-null    float64
#  3   DX         335 non-null    object
#  4   ados_css   190 non-null    float64
#  5   scq_total  325 non-null    float64
#  6   iq         331 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 18.4+ KB

# %%
data_path = "data/CHARM"

# %%
demo = pd.read_csv(data_path + '/tobacco_demographics.csv')

# %%
data = widgets.Dropdown(options=[os.path.basename(x) for x in glob.glob(data_path + '/Desikan_sift2/*')])
display(data)
# Out:
# Dropdown(options=('R0387_V0910_desikan_connmat_sift2.txt', 'R0353_V0783_desikan_connmat_sift2.txt', 'R0346_V07…

# %%
files = [os.path.basename(x) for x in glob.glob(data_path + '/Desikan_sift2/*')]

# %%
a = np.loadtxt(data_path + '/Desikan_sift2/' + files[10])
b = np.loadtxt(data_path + '/Desikan_sift2/' + files[300])

np.fill_diagonal(a, 0)
np.fill_diagonal(b, 0)


fig, axes = plt.subplots(1, 2, figsize=(20,10))
sns.heatmap(a, cmap='RdBu', ax=axes[0])
sns.heatmap(b, cmap='RdBu', ax=axes[1])
# Out:
# <AxesSubplot:>
